# %% [markdown]
# <h1 align="center">Линейные преобразования</h1>

# %% [markdown]
# 1. Найдите собственные векторы и собственные значения для линейного оператора, заданного матрицей:
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$

# %% [markdown]
# $$\begin{vmatrix}
# -1-\lambda & -6\\
# 2 & 6-\lambda
# \end{vmatrix} = 0$$
#
# $$-(1+\lambda)(6-\lambda)-(-6)*2=0$$
#
# $$\lambda^2+\lambda-6\lambda-6+12=0$$
#
# $$\lambda^2-5\lambda+6=0$$
#
# $$ D=25-4*6=1$$
#
# $$ \lambda_{1, 2} = \frac{5\pm1}{2} =\left[
#       \begin{gathered}
#         3 \\
#         2
#       \end{gathered}
# \right.$$
#
# $$\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix},
# \Rightarrow
# \begin{cases}
# x_1\lambda=-x_1-6x_2\\
# x_2\lambda=2x_1+6x_2
# \end{cases},
# $$
# <br/>Для $\lambda = 3$:
# $$
# \begin{cases}
# 3x_1=-x_1-6x_2\\
# 3x_2=2x_1+6x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# x_1=-1.5x_2\\
# 3x_2=-3x_2+6x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# x_1=-1.5\\
# x_2=1
# \end{cases}$$
# <br/>Для $\lambda = 2$:
# $$
# \begin{cases}
# 2x_1=-x_1-6x_2\\
# 2x_2=2x_1+6x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# x_1=-2x_2\\
# 2x_2=-4x_2+6x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# x_1=-2\\
# x_2=1
# \end{cases}$$

# %% [markdown]
# 2. Дан оператор поворота на 180 градусов, задаваемый матрицей:
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Покажите, что __любой__ вектор считается для него собственным.

# %% [markdown]
# $$\begin{vmatrix}
# -1-\lambda & 0\\
# 0 & -1-\lambda
# \end{vmatrix} = 0$$
#
# $$(-1-\lambda)^2=0$$
#
# $$\lambda=-1$$
#
# $$\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix},
# \Rightarrow
# \begin{cases}
# x_1\lambda=-x_1\\
# x_2\lambda=-x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# -x_1=-x_1\\
# -x_2=-x_2
# \end{cases},
# \Rightarrow
# \begin{cases}
# 0=0\\
# 0=0
# \end{cases},
# \Rightarrow
# $$
# <br/>любой вектор для предложенного оператора поворота будет считаться собственным.

# %% [markdown]
# 3. Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# $$\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix},
# \Rightarrow
# \begin{cases}
# \lambda=1*1+1*1\\
# \lambda=(-1)*1+3*1
# \end{cases},
# \Rightarrow
# \begin{cases}
# \lambda=2\\
# \lambda=2
# \end{cases},\Rightarrow
# $$
# <br/>вектор 𝑥=(1,1) является собственным вектором исходного линейного оператора.

# %% [markdown]
# 4. Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix} 0 & 3 & 0\\ 3 & 0 & 0\\ 0 & 0 & 3 \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %% [markdown]
# $$\begin{pmatrix}
# 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 3\\
# -3\\
# -4
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# 3\\
# -3\\
# -4
# \end{pmatrix},
# \Rightarrow
# \begin{cases}
# 3\lambda=-9\\
# -3\lambda=9\\
# -4\lambda=-12
# \end{cases},$$ <br/> что не имеет смысла, поэтому
# вектор $x=(3, -3, -4)$ не является собственным вектором линейного оператора A.
